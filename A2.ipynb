# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
from scipy.stats import zscore

# %%
stud=pd.read_csv("acdemic_data.csv")

# %%
stud.head(10)
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT  DA
# 0        LA      Roy      M  85.0    88   90.0  92
# 1        SA    Dixit      F  90.0    90   94.0  95
# 2        AB   Danial      M   NaN    na  100.0  80
# 3        DA   Kapoor      M  95.0    86  500.0  82
# 4        SA      Jha      F   NaN    84   98.0  84
# 5        WS   Thakur      F  87.0   NaN   97.0  86
# 6        DY   Kapoor      M  81.0    80   96.0  89
# 7        JK   Khanna      F  40.0    88   95.0  87
# 8        RT  Pardesi      M  10.0    96   94.0  88
# 9        UV  Pardesi      M   9.0   NaN   93.0  96

# %%
stud['SPOS'].fillna(stud['SPOS'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_3888/1760691540.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   stud['SPOS'].fillna(stud['SPOS'].mean(),inplace=True)

# %%
stud.head(10)
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT  DA
# 0        LA      Roy      M  85.0    88   90.0  92
# 1        SA    Dixit      F  90.0    90   94.0  95
# 2        AB   Danial      M  99.7    na  100.0  80
# 3        DA   Kapoor      M  95.0    86  500.0  82
# 4        SA      Jha      F  99.7    84   98.0  84
# 5        WS   Thakur      F  87.0   NaN   97.0  86
# 6        DY   Kapoor      M  81.0    80   96.0  89
# 7        JK   Khanna      F  40.0    88   95.0  87
# 8        RT  Pardesi      M  10.0    96   94.0  88
# 9        UV  Pardesi      M   9.0   NaN   93.0  96

# %%
stud['WT_log']=np.log(stud['WT'])

# %%
stud.head(10)
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT  DA    WT_log
# 0        LA      Roy      M  85.0    88   90.0  92  4.499810
# 1        SA    Dixit      F  90.0    90   94.0  95  4.543295
# 2        AB   Danial      M  99.7    na  100.0  80  4.605170
# 3        DA   Kapoor      M  95.0    86  500.0  82  6.214608
# 4        SA      Jha      F  99.7    84   98.0  84  4.584967
# 5        WS   Thakur      F  87.0   NaN   97.0  86  4.574711
# 6        DY   Kapoor      M  81.0    80   96.0  89  4.564348
# 7        JK   Khanna      F  40.0    88   95.0  87  4.553877
# 8        RT  Pardesi      M  10.0    96   94.0  88  4.543295
# 9        UV  Pardesi      M   9.0   NaN   93.0  96  4.532599

# %%
stud['WT_sqrt']=np.sqrt(stud['WT'])

# %%
stud.head(10)
# Out:
#   Firstname Lastname Gender  SPOS DSBDA     WT  DA    WT_log    WT_sqrt
# 0        LA      Roy      M  85.0    88   90.0  92  4.499810   9.486833
# 1        SA    Dixit      F  90.0    90   94.0  95  4.543295   9.695360
# 2        AB   Danial      M  99.7    na  100.0  80  4.605170  10.000000
# 3        DA   Kapoor      M  95.0    86  500.0  82  6.214608  22.360680
# 4        SA      Jha      F  99.7    84   98.0  84  4.584967   9.899495
# 5        WS   Thakur      F  87.0   NaN   97.0  86  4.574711   9.848858
# 6        DY   Kapoor      M  81.0    80   96.0  89  4.564348   9.797959
# 7        JK   Khanna      F  40.0    88   95.0  87  4.553877   9.746794
# 8        RT  Pardesi      M  10.0    96   94.0  88  4.543295   9.695360
# 9        UV  Pardesi      M   9.0   NaN   93.0  96  4.532599   9.643651

# %%
plt.boxplot([stud['WT'],stud['WT_log']],labels=['WT','WT_log'])
plt.show()
# Out:
# /tmp/ipykernel_3888/2980875398.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([stud['WT'],stud['WT_log']],labels=['WT','WT_log'])

# %%
print(stud['WT'])
# Out:
# 0      90.0
# 1      94.0
# 2     100.0
# 3     500.0
# 4      98.0
# 5      97.0
# 6      96.0
# 7      95.0
# 8      94.0
# 9      93.0
# 10      NaN
# 11     88.0
# Name: WT, dtype: float64

# %%
stud['WT'].fillna(stud['WT'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_3888/2401830319.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   stud['WT'].fillna(stud['WT'].mean(),inplace=True)

# %%
print(stud['WT'])
# Out:
# 0      90.000000
# 1      94.000000
# 2     100.000000
# 3     500.000000
# 4      98.000000
# 5      97.000000
# 6      96.000000
# 7      95.000000
# 8      94.000000
# 9      93.000000
# 10    131.363636
# 11     88.000000
# Name: WT, dtype: float64

# %%
plt.boxplot([stud['WT'],stud['WT_log']],labels=['WT','WT_log'])
# Out:
# /tmp/ipykernel_3888/2857536836.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([stud['WT'],stud['WT_log']],labels=['WT','WT_log'])
# {'whiskers': [<matplotlib.lines.Line2D at 0x73f46fc32ce0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x73f46fd4b4c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x73f46fc329e0>,
# ...
#  'medians': [<matplotlib.lines.Line2D at 0x73f46fc331f0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x73f46fc334f0>,
# ...
#  'means': []}

# %%
plt.show()

# %%
print(stud['WT_log'])
# Out:
# 0     4.499810
# 1     4.543295
# 2     4.605170
# 3     6.214608
# 4     4.584967
# 5     4.574711
# 6     4.564348
# 7     4.553877
# 8     4.543295
# 9     4.532599
# 10         NaN
# 11    4.477337
# Name: WT_log, dtype: float64

# %%
plt.boxplot([stud['WT'],stud['WT_log']],labels=['WT','WT_log'])
plt.show()
# Out:
# /tmp/ipykernel_3888/2980875398.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([stud['WT'],stud['WT_log']],labels=['WT','WT_log'])

# %%
df=pd.read_csv("missing.csv")
df.head(10)
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
# 5         5    116.0          74.0        NaN            NaN  25.6
# 6         3     78.0          50.0       32.0           88.0  31.0
# 7        10    115.0           NaN        NaN            NaN  35.3
# 8         2    197.0          70.0       45.0          543.0  30.5
# 9         8    125.0          96.0        NaN            NaN   NaN
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1
# ...

# %%
df['Serum_Insulin'].fillna(df['Serum_Insulin'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_3888/3399467253.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Serum_Insulin'].fillna(df['Serum_Insulin'].mean(),inplace=True)

# %%
df.head(10)
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0     155.548223  33.6
# 1         1     85.0          66.0       29.0     155.548223  26.6
# 2         8    183.0          64.0        NaN     155.548223  23.3
# 3         1     89.0          66.0       23.0      94.000000  28.1
# 4         0    137.0          40.0       35.0     168.000000  43.1
# 5         5    116.0          74.0        NaN     155.548223  25.6
# 6         3     78.0          50.0       32.0      88.000000  31.0
# 7        10    115.0           NaN        NaN     155.548223  35.3
# 8         2    197.0          70.0       45.0     543.000000  30.5
# 9         8    125.0          96.0        NaN     155.548223   NaN
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1
# ...
